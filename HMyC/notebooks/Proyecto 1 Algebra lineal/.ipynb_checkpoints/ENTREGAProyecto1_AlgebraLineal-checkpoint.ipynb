# %% [markdown]
# *Daniel Velasco Rodriguez -
# Cod: 2215456*
#
# #***SOLUCIÓN SISTEMAS DE ECUACIONES LINEALES***
#
# *Solución por medio de la representación matricial $A.x = b$ para cualquier tipo de sistema de ecuaciones lineales ingresando sus matrices por teclado, haciendo uso de la libreria Numpy de Python*
# (Sin gráficas).

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import  Axes3D   #ejes en 3d
from matplotlib import cm  #mapa de colores

# Notación matricial:
# 1.   A * x = b 
# 2.   x = inv(A) * b

##Ingreso de datos del sistema de ecuaciones
print("SOLUCIÓN SISTEMA DE ECUACIONES LINEALES\n\n")
ecuaciones = int(input("N° de ecuaciones: "))
variables = int(input("N° de variables: "))

a = []
b = []

if ecuaciones == variables:   
    for i in range (ecuaciones):
        a.append([0] * variables)
    for i in range (ecuaciones):
        for j in range (variables):
            a[i][j] = float(input("*Fila {}, Columna {}: ".format(i+1 , j+1)))
    print("\n" ,"Matriz A =")

    for fila in a:
        print("[", end= " ")
        for elemento in fila:
            print(" {} ".format(elemento), end= " ")
        print("]")
    print()

##-
    numc = ecuaciones
    b =[]
    while numc <= ecuaciones:
        for k in range(numc):
            b.append(float(input("*Ingrese el valor de los coef independientes: ")))
            if k == 2:
                break
        break
    print("\n" ,"Matriz b =\n" ,b )

    A = np.array(a)
    B = np.array(b)
#------------------------------------IMPORTANTE-----------------------------------------------
#NO HOMOGENEO
#Solución unica         |A| != 0 
#Infinitas soluciones   |A|= 0
#Sin solución           |A| = 0 

#HOMOGENEO (A.x=0)
##Infinitas soluciones  |A| = 0
##Sin solución          |A| != 0
#--------------------------------------------------------------------------------------------
##Compruebo determinante de Matriz A

    if np.linalg.det(A) == 0:
        x = None 
        print("\nSi el sistema NO es homogeneo, NO tiene solución ya que |A| = 0") 
        print("Si el sistema de ecuaciones es homogeneo y |A| = 0, tiene infinitas soluciones")

        h = int(input("\nIngrese 1 si el sistema es homogeneo, de lo contrario ingrese 0: "))

        if h == 1:
            x = np.linalg.lstsq(A,B, rcond=None) 
            print("\nSolución por minimos cuadrados para la ecuación lineal", "\n", "x = ", x)  
        else:
           print("\nNO tiene solución ya que |A| = 0") 
 
    else:       
        x = np.linalg.solve(A,B)
        print("\nSistema no homogeneo \nDeterminante |A| != 0 \nEl sistema tiene solución unica")
        print("\n Vector solución", "\n", "x = ", x)


#INFINITAS SOLUCIONES: Más incognitas que ecuaciones           
else:

    if variables > ecuaciones:
        for i in range (ecuaciones):
            a.append([0] * variables)
        for i in range (ecuaciones):
            for j in range (variables):
                a[i][j] = float(input("*Fila {}, Columna {}: ".format(i+1 , j+1)))
        print("Matriz A =")


        for fila in a:
            print("[", end= " ")
            for elemento in fila:
                print(" {} ".format(elemento), end= " ")
            print("]")
        print()

##-
        numc = ecuaciones
        b =[]

        while numc <= ecuaciones:
            for k in range(numc):
                b.append(float(input("*Ingrese el valor de los coef independientes: ")))
                if k == 2:
                    break
            break
        print("Matriz b =\n" ,b )

##-
        A = np.array(a)
        B = np.array(b)

       ##Solución por minimos cuadrados para la ecuacion lineal
        x = np.linalg.lstsq(A,B, rcond=None) 
        print("\n Solución por minimos cuadrados para la ecuacion lineal", "\n", "x = ", x)
# Out:
# SOLUCIÓN SISTEMA DE ECUACIONES LINEALES
#
#
# N° de ecuaciones: 3
# N° de variables: 3
# *Fila 1, Columna 1: 30
# *Fila 1, Columna 2: 20
# *Fila 1, Columna 3: 20
# *Fila 2, Columna 1: 20
# *Fila 2, Columna 2: 30
# *Fila 2, Columna 3: 20
# *Fila 3, Columna 1: 10
# *Fila 3, Columna 2: 10
# *Fila 3, Columna 3: 10
#
#  Matriz A =
# [  30.0   20.0   20.0  ]
# [  20.0   30.0   20.0  ]
# [  10.0   10.0   10.0  ]
#
# *Ingrese el valor de los coef independientes: 340
# *Ingrese el valor de los coef independientes: 320
# *Ingrese el valor de los coef independientes: 140
#
#  Matriz b =
#  [340.0, 320.0, 140.0]
#
# Sistema no homogeneo
# Determinante |A| != 0
# El sistema tiene solución unica
#
#  Vector solución
#  x =  [6. 4. 4.]

# %% [markdown]
# #***EJERCICIOS***
#
# *Ejercicios del proyecto resueltos de manera individual*.
#
# 1. *Con libreria Numpy.*
# 2. *Por metodos propios.*
# 3. *A mano (En el pdf).*
# 4. *Visualización de graficas generadas con libreria Matplotlib.*

# %% [markdown]
# ##***Ejercicio 1 - Solución única***
# *Un viajero que acaba de regresar de Europa gastó 30 diarios en Inglaterra, 20 diarios en Francia y 20 diarios en España por concepto de hospedaje. En comida gastó 20 diarios en Inglaterra, 30 diarios en Francia y 20 diarios en España. Sus gastos adicionales fueron de 10 diarios en cada país*.
#
# *Los registros del viajero indican que gastó un total de 340 en hospedaje, 320 en comida y 140 en gastos adicionales durante su viaje por estos tres países. Calcule el número de días que pasó el viajero en cada país o muestre que los registros son incorrectos debido a que las cantidades gastadas no son compatibles una con la otra* *texto en cursiva*
#
# $ 30x +20y +20z = 340$ \\
# $ 20x +30y +20z = 320$ \\
# $ 10x + 10y +10z = 140$ \\

# %%
###------------NUMPY------------------------------

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import  Axes3D   #ejes en 3d
from matplotlib import cm  #mapa de colores


A = np.array([[30,20,20],[20,30,20],[10,10,10]])
b = np.array([340,320,140])
sol = np.linalg.solve(A,b)
print(sol)


x,y = np.linspace(0,10,10) , np.linspace(0,10,10)
X,Y = np.meshgrid(x,y)

#Ecuaciones despejadas
Z1 = (340-30*X-20*Y)/20
Z2 = (320-20*X-30*Y)/20
Z3 = (140-10*X-10*Y)/10

fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.plot_surface(X,Y,Z1,alpha=0.5, cmap=cm.Accent,rstride=100, cstride=100)
ax.plot_surface(X,Y,Z2,alpha=0.5, cmap=cm.Paired,rstride=100, cstride=100)
ax.plot_surface(X,Y,Z3,alpha=0.5, cmap=cm.Pastel1,rstride=100, cstride=100)

#Punto de intersección
ax.plot((sol[0],),(sol[1],),(sol[2],), lw=2, c='k' , marker='o', markersize=6)

ax.set_xlabel('X'); ax.set_ylabel('Y'), ax.set_zlabel('Z')


plt.show()
# Out:
# [6. 4. 4.]

# %%
##----------------METODOS PROPIOS: SUSTITUCIÓN HACIA ATRAS

m = int(input("Valor de m (Ecuaciones): "))
n = int(input("Valor de n (Variables): "))

matrix = np.zeros((m,n))
vector= np.zeros((n))
x=np.zeros((m))

print("Introduce la matriz de coeficientes: ")

for r in range(0,m):
    for c in range(0,n):
        matrix[(r),(c)]=(input("Elemento a["+str(r+1)+","+str(c+1)+"] "))
    vector[(r)]=(input('b[]: '))
print(matrix)


for k in range (0,m):
    for r in range(k+1,m):
        factor=(matrix[r,k]/matrix[k,k])
        vector[r]=vector[r]-(factor*vector[k])

        for c in range(0,n):
            matrix[r,c]=matrix[r,c]-(factor*matrix[k,c])

#sustitución hacia atrás

x[m-1]=vector[m-1]/matrix[m-1,m-1]
print (x[m-1])

for r in range(m-2,-1,-1):
    suma=0;
    for c in range(0,n):
        suma=suma+matrix[r,c]*x[c]
    x[r]=(vector[r]-suma)/matrix[r,r]


print("\nResultado matriz")
print(matrix)

print("\nResultados: ")
print(x)

x,y = np.linspace(0,10,10) , np.linspace(0,10,10)
X,Y = np.meshgrid(x,y)

#Ecuaciones despejadas
Z1 = (340-30*X-20*Y)/20
Z2 = (320-20*X-30*Y)/20
Z3 = (140-10*X-10*Y)/10

fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.plot_surface(X,Y,Z1,alpha=0.5, cmap=cm.Accent,rstride=100, cstride=100)
ax.plot_surface(X,Y,Z2,alpha=0.5, cmap=cm.Paired,rstride=100, cstride=100)
ax.plot_surface(X,Y,Z3,alpha=0.5, cmap=cm.Pastel1,rstride=100, cstride=100)

#Punto de intersección
ax.plot((sol[0],),(sol[1],),(sol[2],), lw=2, c='k' , marker='o', markersize=6)

ax.set_xlabel('X'); ax.set_ylabel('Y'), ax.set_zlabel('Z')


plt.show()
# Out:
# Valor de m: 3
# Valor de n: 3
# Introduce la matriz de coeficientes y el vector solución
# Elemento a[1,1] 30
# Elemento a[1,2] 20
# Elemento a[1,3] 20
# b[]: 340
# Elemento a[2,1] 20
# Elemento a[2,2] 30
# Elemento a[2,3] 20
# b[]: 320
# Elemento a[3,1] 10
# Elemento a[3,2] 10
# Elemento a[3,3] 10
# b[]: 140
# [[30. 20. 20.]
#  [20. 30. 20.]
#  [10. 10. 10.]]
# 4.000000000000002
# Resultado matriz
# [[30.         20.         20.        ]
#  [ 0.         16.66666667  6.66666667]
#  [ 0.          0.          2.        ]]
# Resultado del vector
# [340.          93.33333333   8.        ]
# Resultados:
# [6. 4. 4.]

# %% [markdown]
# ##***Ejercicio 2 - Solución única***
# *Modelo de Leontief aplicado a un sistema económico con tres industrias - Pag 18 algebra lineal, Grossman.*
#
# *Suponga que las demandas externas en un sistema económico con tres industrias son 10, 25 y
# 20, respectivamente.*
#
# *Suponga que* \\
#
#
# $a11=0.2; \ \ a12=0.5; \ \ a13=0.15 \\ a21=0.4; \ \ a22=0.1; \ \ a23=0.3 \\
# a31 =0.25; \ \ a32=0.5; \ \ a33=0.15 \\ $
#
# *Encuentre la producción de cada industria de manera que la oferta sea exactamente igual a la demanda.* \\
#
# $ 0.8x - 0.5y - 0.15z = 10$ \\
# $ -0.4x + 0.9y - 0.3z = 25$ \\
# $ -0.25x - 0.5y +0.85z = 20$ \\

# %%
##----------NUMPY

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import  Axes3D   #ejes en 3d
from matplotlib import cm  #mapa de colores


A = np.array([[0.8,-0.5,-0.15],[-0.4,0.9,-0.3],[-0.25,-0.5,0.85]])
b = np.array([10,25,20])
sol = np.linalg.solve(A,b)
print(sol)


x,y = np.linspace(0,1000,100) , np.linspace(0,1000,100)
X,Y = np.meshgrid(x,y)

#Ecuaciones despejadas
Z1 = (10 - 0.8*X+0.5*Y)/-0.15
Z2 = (25+0.4*X - 0.9*Y)/-0.3
Z3 = (20+0.25*X+0.5*Y)/0.85

fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.plot_surface(X,Y,Z1,alpha=0.5, cmap=cm.Accent,rstride=100, cstride=100)
ax.plot_surface(X,Y,Z2,alpha=0.5, cmap=cm.Paired,rstride=100, cstride=100)
ax.plot_surface(X,Y,Z3,alpha=0.5, cmap=cm.Pastel1,rstride=100, cstride=100)

#Punto de intersección
ax.plot((sol[0],),(sol[1],),(sol[2],), lw=2, c='k' , marker='o', markersize=6)

ax.set_xlabel('X'); ax.set_ylabel('Y'), ax.set_zlabel('Z')


plt.show()
# Out:
# [110.30577576 118.74292186 125.82106455]

# %%
##-------------METODOS PROPIOS: SUSTITUCIÓN HACIA ATRAS


m = int(input("Valor de m (Ecuaciones): "))
n = int(input("Valor de n (Variables): "))

matrix = np.zeros((m,n))
vector= np.zeros((n))
x=np.zeros((m))

print("Introduce la matriz de coeficientes: ")

for r in range(0,m):
    for c in range(0,n):
        matrix[(r),(c)]=(input("Elemento a["+str(r+1)+","+str(c+1)+"] "))
    vector[(r)]=(input('b[]: '))
print(matrix)


for k in range (0,m):
    for r in range(k+1,m):
        factor=(matrix[r,k]/matrix[k,k])
        vector[r]=vector[r]-(factor*vector[k])

        for c in range(0,n):
            matrix[r,c]=matrix[r,c]-(factor*matrix[k,c])

#sustitución hacia atrás

x[m-1]=vector[m-1]/matrix[m-1,m-1]
print (x[m-1])

for r in range(m-2,-1,-1):
    suma=0;
    for c in range(0,n):
        suma=suma+matrix[r,c]*x[c]
    x[r]=(vector[r]-suma)/matrix[r,r]


print("\nResultado matriz")
print(matrix)
print ("\nResultado del vector")
print(vector)
print("\nResultados: ")
print(x)

x,y = np.linspace(0,1000,100) , np.linspace(0,1000,100)
X,Y = np.meshgrid(x,y)

#Ecuaciones despejadas
Z1 = (10 - 0.8*X+0.5*Y)/-0.15
Z2 = (25+0.4*X - 0.9*Y)/-0.3
Z3 = (20+0.25*X+0.5*Y)/0.85

fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.plot_surface(X,Y,Z1,alpha=0.5, cmap=cm.Accent,rstride=100, cstride=100)
ax.plot_surface(X,Y,Z2,alpha=0.5, cmap=cm.Paired,rstride=100, cstride=100)
ax.plot_surface(X,Y,Z3,alpha=0.5, cmap=cm.Pastel1,rstride=100, cstride=100)

#Punto de intersección
ax.plot((sol[0],),(sol[1],),(sol[2],), lw=2, c='k' , marker='o', markersize=6)

ax.set_xlabel('X'); ax.set_ylabel('Y'), ax.set_zlabel('Z')


plt.show()
# Out:
# Valor de m: 3
# Valor de n: 3
# Introduce la matriz de coeficientes y el vector solución
# Elemento a[1,1] 0.8
# Elemento a[1,2] -0.5
# Elemento a[1,3] -0.15
# b[]: 10
# Elemento a[2,1] -0.4
# Elemento a[2,2] 0.9
# Elemento a[2,3] -0.3
# b[]: 25
# Elemento a[3,1] -0.25
# Elemento a[3,2] -0.5
# Elemento a[3,3] 0.85
# b[]: 20
# [[ 0.8  -0.5  -0.15]
#  [-0.4   0.9  -0.3 ]
#  [-0.25 -0.5   0.85]]
# 125.82106455266137
# Resultado matriz
# [[ 0.8        -0.5        -0.15      ]
#  [ 0.          0.65       -0.375     ]
#  [ 0.          0.          0.42451923]]
# Resultado del vector
# [10.         30.         53.41346154]
# Resultados:
# [110.30577576 118.74292186 125.82106455]

# %% [markdown]
# ##***Ejercicio 3 - Solución única***
#
# *Una embotelladora de refrescos desea cotizar la publicidad de sus productos en televisión, radio y revista, se tienen tres propuestas del plan de medios de acuerdo con el presupuesto asignado acerca de la cantidad de anuncios por medio en el transcurso de un mes.*
#
# *En el primer presupuesto cada anuncio en televisión tiene un coste de 250.000, en radio 5.000 y en revista 30.000. En el segundo presupuesto 310.000, 4.000 y 15.000 y en el último presupuesto 560000, 10.000 y 35.000. Los totales por presupuesto son los siguientes: 2.1795.000, 3.1767.000 y 61.225.000.* \\
#
#
#
# *Determine la cantidad de anuncios cotizados por cada medio.* \\
#
# $ 250x + 5y + 30z = 21795$ \\
# $ 310x + 4y + 15z = 31767$ \\
# $ 560x + 10y + 35z = 61225$ \\

# %%
##----------NUMPY

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import  Axes3D   #ejes en 3d
from matplotlib import cm  #mapa de colores


A = np.array([[250,5,30],[310,4,15],[560,10,35]])
b = np.array([21795,31767,61225])
sol = np.linalg.solve(A,b)
print(sol)


x,y = np.linspace(0,1000,100) , np.linspace(0,1000,100)
X,Y = np.meshgrid(x,y)

#Ecuaciones despejadas
Z1 = (21795-250*X-5*Y)/30
Z2 = (31767-310*X-4*Y)/15
Z3 = (61225-560*X-10*Y)/35

fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.plot_surface(X,Y,Z1,alpha=0.5, cmap=cm.Accent,rstride=100, cstride=100)
ax.plot_surface(X,Y,Z2,alpha=0.5, cmap=cm.Paired,rstride=100, cstride=100)
ax.plot_surface(X,Y,Z3,alpha=0.5, cmap=cm.Pastel1,rstride=100, cstride=100)


ax.set_xlabel('X'); ax.set_ylabel('Y'), ax.set_zlabel('Z')


plt.show()
# Out:
# [  90.29864253 2776.16742081 -488.68325792]

# %%
##-------------METODOS PROPIOS: SUSTITUCIÓN HACIA ATRAS

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import  Axes3D   #ejes en 3d
from matplotlib import cm  #mapa de colores

m = int(input("Valor de m (Ecuaciones): "))
n = int(input("Valor de n (Variables): "))
matrix = np.zeros((m,n))
vector= np.zeros((n))
x=np.zeros((m))

print("Introduce la matriz de coeficientes: ")

for r in range(0,m):
    for c in range(0,n):
        matrix[(r),(c)]=(input("Elemento a["+str(r+1)+","+str(c+1)+"] "))
    vector[(r)]=(input('b[]: '))
print(matrix)


for k in range (0,m):
    for r in range(k+1,m):
        factor=(matrix[r,k]/matrix[k,k])
        vector[r]=vector[r]-(factor*vector[k])

        for c in range(0,n):
            matrix[r,c]=matrix[r,c]-(factor*matrix[k,c])

#sustitución hacia atrás

x[m-1]=vector[m-1]/matrix[m-1,m-1]
print (x[m-1])

for r in range(m-2,-1,-1):
    suma=0;
    for c in range(0,n):
        suma=suma+matrix[r,c]*x[c]
    x[r]=(vector[r]-suma)/matrix[r,r]


print("\nResultado matriz")
print(matrix)
print ("\nResultado del vector")
print(vector)
print("\nResultados: ")
print(x)


x,y = np.linspace(0,1000,100) , np.linspace(0,1000,100)
X,Y = np.meshgrid(x,y)

#Ecuaciones despejadas
Z1 = (21795-250*X-5*Y)/30
Z2 = (31767-310*X-4*Y)/15
Z3 = (61225-560*X-10*Y)/35

fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.plot_surface(X,Y,Z1,alpha=0.5, cmap=cm.Accent,rstride=1000, cstride=1000)
ax.plot_surface(X,Y,Z2,alpha=0.5, cmap=cm.Paired,rstride=1000, cstride=1000)
ax.plot_surface(X,Y,Z3,alpha=0.5, cmap=cm.Pastel1,rstride=1000, cstride=1000)


ax.set_xlabel('X'); ax.set_ylabel('Y'), ax.set_zlabel('Z')


plt.show()
# Out:
# Valor de m (Ecuaciones): 3
# Valor de n (Variables): 3
# Introduce la matriz de coeficientes:
# Elemento a[1,1] 250
# Elemento a[1,2] 5
# Elemento a[1,3] 30
# b[]: 21795
# Elemento a[2,1] 310
# Elemento a[2,2] 4
# Elemento a[2,3] 15
# b[]: 31767
# Elemento a[3,1] 560
# Elemento a[3,2] 10
# Elemento a[3,3] 35
# b[]: 61225
# [[250.   5.  30.]
#  [310.   4.  15.]
#  [560.  10.  35.]]
# -488.683257918552
#
# Resultado matriz
# [[250.           5.          30.        ]
#  [  0.          -2.2        -22.2       ]
#  [  0.           0.         -20.09090909]]
#
# Resultado del vector
# [21795.          4741.2         9818.09090909]
#
# Resultados:
# [  90.29864253 2776.16742081 -488.68325792]

# %% [markdown]
# ##***Ejercicio 4 - Infinitas soluciones***
#
#
#
#
#
# $ 2x + 4y + 6z = 18$ \\
# $ 4x + 5y + 6z = 24$ \\
# $ 2x + 7y + 12z = 30$ \\

# %%
###---------------NUMPY---------

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import  Axes3D   #ejes en 3d
from matplotlib import cm  #mapa de colores

print("SOLUCIÓN SISTEMA DE ECUACIONES LINEALES\n\n")
ecuaciones = int(input("N° de ecuaciones: "))
variables = int(input("N° de variables: "))

a = []

if variables == ecuaciones:


        for i in range (ecuaciones):
            a.append([0] * variables)

        for i in range (ecuaciones):
            for j in range (variables):
                a[i][j] = float(input("*Fila {}, Columna {}: ".format(i+1 , j+1)))

        print("Matriz A =")
        for fila in a:
            print("[", end= " ")
            for elemento in fila:
                print(" {} ".format(elemento), end= " ")
            print("]")
        print()
##-
        numc = ecuaciones
        b =[]

        while numc <= ecuaciones:
            for k in range(numc):
                b.append(float(input("*Ingrese el valor de los coef independientes: ")))
                if k == 2:
                    break
            break
        print("Matriz b =\n" ,b )

##-
        A = np.array(a)
        B = np.array(b)

        ##Solución por minimos cuadrados para la ecuacion lineal
        x = np.linalg.lstsq(A,B, rcond=None)
        print("\nEl sistema tiene infinitas soluciones")
        print("\nSolución por minimos cuadrados para la ecuacion lineal", "\n", "x = ", x)


x,y = np.linspace(0,1000,100) , np.linspace(0,1000,100)
X,Y = np.meshgrid(x,y)

#Ecuaciones despejadas
Z1 = (18 - 2*X-4*Y)/6
Z2 = (24 -4*X-5*Y)/6
Z3 = (30 - 2*X - 7*Y)/12

fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.plot_surface(X,Y,Z1,alpha=0.5, cmap=cm.Accent,rstride=1000, cstride=1000)
ax.plot_surface(X,Y,Z2,alpha=0.5, cmap=cm.Paired,rstride=1000, cstride=1000)
ax.plot_surface(X,Y,Z3,alpha=0.5, cmap=cm.Pastel1,rstride=1000, cstride=1000)

#Punto de intersección
# ax.plot((sol[0],),(sol[1],),(sol[2],), lw=2, c='k' , marker='o', markersize=6)

ax.set_xlabel('X'); ax.set_ylabel('Y'), ax.set_zlabel('Z')
plt.show()
# Out:
# SOLUCIÓN SISTEMA DE ECUACIONES LINEALES
#
#
# N° de ecuaciones: 3
# N° de variables: 3
# *Fila 1, Columna 1: 2
# *Fila 1, Columna 2: 4
# *Fila 1, Columna 3: 6
# *Fila 2, Columna 1: 4
# *Fila 2, Columna 2: 5
# *Fila 2, Columna 3: 6
# *Fila 3, Columna 1: 2
# *Fila 3, Columna 2: 7
# *Fila 3, Columna 3: 12
# Matriz A =
# [  2.0   4.0   6.0  ]
# [  4.0   5.0   6.0  ]
# [  2.0   7.0   12.0  ]
#
# *Ingrese el valor de los coef independientes: 18
# *Ingrese el valor de los coef independientes: 24
# *Ingrese el valor de los coef independientes: 30
# Matriz b =
#  [18.0, 24.0, 30.0]
#
# El sistema tiene infinitas soluciones
#
# Solución por minimos cuadrados para la ecuacion lineal
#  x =  (array([2.16666667, 1.66666667, 1.16666667]), array([], dtype=float64), 2, array([1.79620616e+01, 2.71373251e+00, 1.32840090e-15]))

# %% [markdown]
# ##***Ejercicio 5 - Infinitas soluciones***
# *Un fabricante produce tres tipos diferentes de productos
# químicos: A, B y C. Cada producto debe pasar por dos máquinas de procesamiento:
# X y Y. La manufactura del producto requiere los tiempos siguientes en las máquinas X y Y:*
# 1. *Una tonelada de A requiere 2 horas en la máquina X y 2 horas en la máquina Y.*
# 2. *Una tonelada de B requiere 3 horas en la máquina X y 2 horas en la máquina Y.*
# 3. *Una tonelada de C requiere 4 horas en la máquina X y 3 horas en la máquina Y.*
#
# *La máquina X está disponible durante 80 horas a la semana, y la máquina Y puede utilizarse 60 horas a la semana. Como la gerencia no quiere que las costosas máquinas X
# y Y estén ociosas, le gustaría saber cuántas toneladas debe manufacturar de cada producto, de modo que las máquinas se utilicen a su capacidad total.*
#
# $ 2x + 3y + 4z = 80$ \\
# $ 2x + 2y + 3z = 60$

# %%
###---------------NUMPY---------

import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import  Axes3D   #ejes en 3d
from matplotlib import cm  #mapa de colores

print("SOLUCIÓN SISTEMA DE ECUACIONES LINEALES\n\n")
ecuaciones = int(input("N° de ecuaciones: "))
variables = int(input("N° de variables: "))

a = []

if variables > ecuaciones:

        for i in range (ecuaciones):
            a.append([0] * variables)

        for i in range (ecuaciones):
            for j in range (variables):
                a[i][j] = float(input("*Fila {}, Columna {}: ".format(i+1 , j+1)))

        print("Matriz A =")
        for fila in a:
            print("[", end= " ")
            for elemento in fila:
                print(" {} ".format(elemento), end= " ")
            print("]")
        print()
##-
        numc = ecuaciones
        b =[]

        while numc <= ecuaciones:
            for k in range(numc):
                b.append(float(input("*Ingrese el valor de los coef independientes: ")))
                if k == 2:
                    break
            break
        print("Matriz b =\n" ,b )

##-
        A = np.array(a)
        B = np.array(b)

        ##Solución por minimos cuadrados para la ecuacion lineal
        x = np.linalg.lstsq(A,B, rcond=None)
        print("\n Solución por minimos cuadrados para la ecuacion lineal", "\n", "x = ", x)


        x,y = np.linspace(0,1000,100) , np.linspace(0,1000,100)
X,Y = np.meshgrid(x,y)

#Ecuaciones despejadas
Z1 = (80 - 2*X-3*Y)/4
Z2 = (60 -2*X-2*Y)/3


fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
ax.plot_surface(X,Y,Z1,alpha=0.5, cmap=cm.Accent,rstride=1000, cstride=1000)
ax.plot_surface(X,Y,Z2,alpha=0.5, cmap=cm.Paired,rstride=1000, cstride=1000)


#Punto de intersección
# ax.plot((sol[0],),(sol[1],),(sol[2],), lw=2, c='k' , marker='o', markersize=6)

ax.set_xlabel('X'); ax.set_ylabel('Y'), ax.set_zlabel('Z')


plt.show()
# Out:
# SOLUCIÓN SISTEMA DE ECUACIONES LINEALES
#
#
# N° de ecuaciones: 2
# N° de variables: 3
# *Fila 1, Columna 1: 2
# *Fila 1, Columna 2: 3
# *Fila 1, Columna 3: 4
# *Fila 2, Columna 1: 2
# *Fila 2, Columna 2: 2
# *Fila 2, Columna 3: 3
# Matriz A =
# [  2.0   3.0   4.0  ]
# [  2.0   2.0   3.0  ]
#
# *Ingrese el valor de los coef independientes: 80
# *Ingrese el valor de los coef independientes: 60
# Matriz b =
#  [80.0, 60.0]
#
#  Solución por minimos cuadrados para la ecuacion lineal
#  x =  (array([ 4.44444444,  8.88888889, 11.11111111]), array([], dtype=float64), 2, array([6.76782894, 0.44327362]))

# %% [markdown]
# ##***SOLUCIÓN DE SISTEMAS DE ECUACIONES POR GAUSS***

# %%
# Método de Gauss
# Solución a Sistemas de Ecuaciones
# de la forma A.X=B

import numpy as np

# INGRESO
A = np.array([[2,4,6],
              [4,5,6],
              [2,7,12]])

B = np.array([[18],
              [24],
              [30]])

# PROCEDIMIENTO
casicero = 1e-15 # Considerar como 0

# Evitar truncamiento en operaciones
A = np.array(A,dtype=float) 

# Matriz aumentada
AB  = np.concatenate((A,B),axis=1)
AB0 = np.copy(AB)

# Pivoteo parcial por filas
tamano = np.shape(AB)
n = tamano[0]
m = tamano[1]

# Para cada fila en AB
for i in range(0,n-1,1):
    # columna desde diagonal i en adelante
    columna  = abs(AB[i:,i])
    dondemax = np.argmax(columna)
    
    # dondemax no está en diagonal
    if (dondemax !=0):
        # intercambia filas
        temporal = np.copy(AB[i,:])
        AB[i,:] = AB[dondemax+i,:]
        AB[dondemax+i,:] = temporal
AB1 = np.copy(AB)

# eliminación hacia adelante
for i in range(0,n-1,1):
    pivote   = AB[i,i]
    adelante = i + 1
    for k in range(adelante,n,1):
        factor  = AB[k,i]/pivote
        AB[k,:] = AB[k,:] - AB[i,:]*factor

# sustitución hacia atrás
ultfila = n-1
ultcolumna = m-1
X = np.zeros(n,dtype=float)

for i in range(ultfila,0-1,-1):
    suma = 0
    for j in range(i+1,ultcolumna,1):
        suma = suma + AB[i,j]*X[j]
    b = AB[i,ultcolumna]
    X[i] = (b-suma)/AB[i,i]

X = np.transpose([X])


# SALIDA
print('Matriz aumentada:')
print(AB0)
print('Pivoteo parcial por filas')
print(AB1)
print('eliminación hacia adelante')
print(AB)
print('solución: ')
print(X)
# Out:
# Matriz aumentada:
# [[ 2.  4.  6. 18.]
#  [ 4.  5.  6. 24.]
#  [ 2.  7. 12. 30.]]
# Pivoteo parcial por filas
# [[ 4.  5.  6. 24.]
#  [ 2.  7. 12. 30.]
#  [ 2.  4.  6. 18.]]
# eliminación hacia adelante
# [[ 4.   5.   6.  24. ]
#  [ 0.   4.5  9.  18. ]
#  [ 0.   0.   0.   0. ]]
# solución:
# [[nan]
#  [nan]
#  [nan]]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:63: RuntimeWarning: invalid value encountered in double_scalars

# %%
####BORRADOR CODIGOS DE PRUEBA

import numpy



m = int(input("Valor de m: "))
n = int(input("Valor de n: "))
matrix = numpy.zeros((m,n))
vector= numpy.zeros((n))
x=numpy.zeros((m))

print("Introduce la matriz de coeficientes y el vector solución")

for r in range(0,m):
    for c in range(0,n):
        matrix[(r),(c)]=(input("Elemento a["+str(r+1)+","+str(c+1)+"] "))
    vector[(r)]=(input('b[]: '))
print(matrix)


for k in range (0,m):
    for r in range(k+1,m):
        factor=(matrix[r,k]/matrix[k,k])
        vector[r]=vector[r]-(factor*vector[k])

        for c in range(0,n):
            matrix[r,c]=matrix[r,c]-(factor*matrix[k,c])

#sustitución hacia atrás

x[m-1]=vector[m-1]/matrix[m-1,m-1]
print (x[m-1])

for r in range(m-2,-1,-1):
    suma=0;
    for c in range(0,n):
        suma=suma+matrix[r,c]*x[c]
    x[r]=(vector[r]-suma)/matrix[r,r]


print("Resultado matriz")
print(matrix)
print ("Resultado del vector")
print(vector)
print("Resultados: ")
print(x)
# Out:
# Valor de m: 2
# Valor de n: 2
# Introduce la matriz de coeficientes y el vector solución
# Elemento a[1,1] 15
# Elemento a[1,2] 12
# b[]: 2
# Elemento a[2,1] 15
# Elemento a[2,2] 16
# b[]: 3
# [[15. 12.]
#  [15. 16.]]
# 0.25
# Resultado matriz
# [[15. 12.]
#  [ 0.  4.]]
# Resultado del vector
# [2. 1.]
# Resultados:
# [-0.06666667  0.25      ]
